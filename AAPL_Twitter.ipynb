# %%
import pandas as pd

# Reads the json generated from the CLI commands above and creates a pandas dataframe
tweets_df1 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/applemarch.json', lines=True)
tweets_df1
# Out:
#                                                      url  \
# 0      https://twitter.com/ExactOptionPick/status/124...
# 1      https://twitter.com/treabase/status/1245137572...
# 2      https://twitter.com/WolfOfWeedST/status/124513...
# 3      https://twitter.com/EliteOptions2/status/12451...
# 4      https://twitter.com/PortfolioBuzz/status/12451...
# ...                                                  ...
# 28087  https://twitter.com/PortfolioBuzz/status/12339...
# 28088  https://twitter.com/teshen8lin/status/12339065...
# 28089  https://twitter.com/options_t/status/123390595...
# 28090  https://twitter.com/michaellistman/status/1233...
# 28091  https://twitter.com/michaellistman/status/1233...
#
#                            date  \
# 0     2020-03-31 23:59:09+00:00
# 1     2020-03-31 23:55:05+00:00
# 2     2020-03-31 23:53:20+00:00
# 3     2020-03-31 23:45:53+00:00
# 4     2020-03-31 23:42:14+00:00
# ...                         ...
# 28087 2020-03-01 00:17:37+00:00
# ...

# %%
tweets_df2 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/appleapril.json', lines=True)
tweets_df2
# Out:
#                                                      url  \
# 0      https://twitter.com/gannonbreslin/status/12560...
# 1      https://twitter.com/aaaamhim/status/1256010296...
# 2      https://twitter.com/aaaamhim/status/1256010049...
# 3      https://twitter.com/aaaamhim/status/1256009845...
# 4      https://twitter.com/StckPro/status/12560096974...
# ...                                                  ...
# 25874  https://twitter.com/MITickWatcher/status/12451...
# 25875  https://twitter.com/JonathanQuiroz/status/1245...
# 25876  https://twitter.com/truthntrading/status/12451...
# 25877  https://twitter.com/FireTrading_/status/124513...
# 25878  https://twitter.com/FireTrading_/status/124513...
#
#                            date  \
# 0     2020-04-30 23:59:35+00:00
# 1     2020-04-30 23:59:24+00:00
# 2     2020-04-30 23:58:26+00:00
# 3     2020-04-30 23:57:37+00:00
# 4     2020-04-30 23:57:02+00:00
# ...                         ...
# 25874 2020-04-01 00:05:02+00:00
# ...

# %%
tweets_df3 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/applemay.json', lines=True)
tweets_df3
# Out:
#                                                      url  \
# 0      https://twitter.com/Stonefoxcapital/status/126...
# 1      https://twitter.com/ElazarAdvisors/status/1267...
# 2      https://twitter.com/DomMagliano/status/1267240...
# 3      https://twitter.com/newsfilterio/status/126724...
# 4      https://twitter.com/StckPro/status/12672397153...
# ...                                                  ...
# 25736  https://twitter.com/DotyBilly/status/125601092...
# 25737  https://twitter.com/flynfresh4eva/status/12560...
# 25738  https://twitter.com/11Graphs/status/1256010635...
# 25739  https://twitter.com/Dwyanosaurus/status/125601...
# 25740  https://twitter.com/Time4Pizza/status/12560105...
#
#                            date  \
# 0     2020-05-31 23:59:28+00:00
# 1     2020-05-31 23:51:15+00:00
# 2     2020-05-31 23:45:52+00:00
# 3     2020-05-31 23:45:40+00:00
# 4     2020-05-31 23:41:06+00:00
# ...                         ...
# 25736 2020-05-01 00:01:54+00:00
# ...

# %%
tweets_df4 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/aaplejune.json', lines=True)
tweets_df4
# Out:
#                                                      url  \
# 0      https://twitter.com/ExactOptionPick/status/127...
# 1      https://twitter.com/25k250/status/127811568329...
# 2      https://twitter.com/TradeLikeGates/status/1278...
# 3      https://twitter.com/musicnews360/status/127811...
# 4      https://twitter.com/commodi08973633/status/127...
# ...                                                  ...
# 34873  https://twitter.com/PortfolioBuzz/status/12672...
# 34874  https://twitter.com/mikeo188/status/1267246313...
# 34875  https://twitter.com/Richard_Rangel_/status/126...
# 34876  https://twitter.com/Richard_Rangel_/status/126...
# 34877  https://twitter.com/TheExtraIncome/status/1267...
#
#                            date  \
# 0     2020-06-30 23:59:05+00:00
# 1     2020-06-30 23:58:19+00:00
# 2     2020-06-30 23:55:58+00:00
# 3     2020-06-30 23:55:40+00:00
# 4     2020-06-30 23:54:37+00:00
# ...                         ...
# 34873 2020-06-01 00:12:42+00:00
# ...

# %%
tweets_df5 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/applejuly.json', lines=True)
tweets_df5
# Out:
#                                                      url  \
# 0      https://twitter.com/marketing1991t1/status/128...
# 1      https://twitter.com/BulldudeC/status/128935004...
# 2      https://twitter.com/OptionBulls/status/1289349...
# 3      https://twitter.com/ncarbo_/status/12893496972...
# 4      https://twitter.com/marketing1991t1/status/128...
# ...                                                  ...
# 46669  https://twitter.com/stockharbinger/status/1278...
# 46670  https://twitter.com/freefdacalendar/status/127...
# 46671  https://twitter.com/jccordero28/status/1278117...
# 46672  https://twitter.com/XMCapitalGroup/status/1278...
# 46673  https://twitter.com/mrkotch/status/12781168861...
#
#                            date  \
# 0     2020-07-31 23:59:59+00:00
# 1     2020-07-31 23:59:40+00:00
# 2     2020-07-31 23:59:20+00:00
# 3     2020-07-31 23:58:17+00:00
# 4     2020-07-31 23:58:04+00:00
# ...                         ...
# 46669 2020-07-01 00:04:56+00:00
# ...

# %%
tweets_df6 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/appleaugust.json', lines=True)
tweets_df6
# Out:
#                                                      url  \
# 0      https://twitter.com/LowFiiiii/status/130058382...
# 1      https://twitter.com/stoxline/status/1300583730...
# 2      https://twitter.com/SteelNicho/status/13005834...
# 3      https://twitter.com/androider25/status/1300583...
# 4      https://twitter.com/UStock5/status/13005833857...
# ...                                                  ...
# 65521  https://twitter.com/vcd_87/status/128935063136...
# 65522  https://twitter.com/IceColdTrades/status/12893...
# 65523  https://twitter.com/LayanSavithra/status/12893...
# 65524  https://twitter.com/spectre_trades/status/1289...
# 65525  https://twitter.com/LashaKrikheli/status/12893...
#
#                            date  \
# 0     2020-08-31 23:58:43+00:00
# 1     2020-08-31 23:58:19+00:00
# 2     2020-08-31 23:57:21+00:00
# 3     2020-08-31 23:57:12+00:00
# 4     2020-08-31 23:56:57+00:00
# ...                         ...
# 65521 2020-08-01 00:02:00+00:00
# ...

# %%
tweets_df7 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/appleseptember.json', lines=True)
tweets_df7
# Out:
#                                                      url  \
# 0      https://twitter.com/stonkscheer/status/1311455...
# 1      https://twitter.com/sonycomeback/status/131145...
# 2      https://twitter.com/PortfolioBuzz/status/13114...
# 3      https://twitter.com/David_Beharall/status/1311...
# 4      https://twitter.com/StockMarketalk/status/1311...
# ...                                                  ...
# 63093  https://twitter.com/CfdForum/status/1300584885...
# 63094  https://twitter.com/StockBrother_/status/13005...
# 63095  https://twitter.com/myrage37/status/1300584788...
# 63096  https://twitter.com/_ms_izzy/status/1300584479...
# 63097  https://twitter.com/pas_fou1972/status/1300584...
#
#                            date  \
# 0     2020-09-30 23:58:42+00:00
# 1     2020-09-30 23:58:29+00:00
# 2     2020-09-30 23:57:14+00:00
# 3     2020-09-30 23:55:00+00:00
# 4     2020-09-30 23:54:20+00:00
# ...                         ...
# 63093 2020-09-01 00:02:55+00:00
# ...

# %%
frames = [tweets_df1, tweets_df2, tweets_df3,tweets_df4,tweets_df5,tweets_df6,tweets_df7]
result = pd.concat(frames)

# %%
result.reset_index(inplace=True)

# %%
from datetime import datetime
result['Date'] = result['date'].dt.date

# %%
result
# Out:
#         index                                                url  \
# 0           0  https://twitter.com/ExactOptionPick/status/124...
# 1           1  https://twitter.com/treabase/status/1245137572...
# 2           2  https://twitter.com/WolfOfWeedST/status/124513...
# 3           3  https://twitter.com/EliteOptions2/status/12451...
# 4           4  https://twitter.com/PortfolioBuzz/status/12451...
# ...       ...                                                ...
# 280606  63093  https://twitter.com/CfdForum/status/1300584885...
# 280607  63094  https://twitter.com/StockBrother_/status/13005...
# 280608  63095  https://twitter.com/myrage37/status/1300584788...
# 280609  63096  https://twitter.com/_ms_izzy/status/1300584479...
# 280610  63097  https://twitter.com/pas_fou1972/status/1300584...
#
#                             date  \
# 0      2020-03-31 23:59:09+00:00
# 1      2020-03-31 23:55:05+00:00
# 2      2020-03-31 23:53:20+00:00
# 3      2020-03-31 23:45:53+00:00
# ...

# %%
dates = list(pd.date_range(start="2020-03-01",end="2021-03-31"))
dates
# Out:
# [Timestamp('2020-03-01 00:00:00', freq='D'),
#  Timestamp('2020-03-02 00:00:00', freq='D'),
#  Timestamp('2020-03-03 00:00:00', freq='D'),
#  Timestamp('2020-03-04 00:00:00', freq='D'),
#  Timestamp('2020-03-05 00:00:00', freq='D'),
#  Timestamp('2020-03-06 00:00:00', freq='D'),
#  Timestamp('2020-03-07 00:00:00', freq='D'),
#  Timestamp('2020-03-08 00:00:00', freq='D'),
#  Timestamp('2020-03-09 00:00:00', freq='D'),
#  Timestamp('2020-03-10 00:00:00', freq='D'),
#  Timestamp('2020-03-11 00:00:00', freq='D'),
#  Timestamp('2020-03-12 00:00:00', freq='D'),
#  Timestamp('2020-03-13 00:00:00', freq='D'),
#  Timestamp('2020-03-14 00:00:00', freq='D'),
#  Timestamp('2020-03-15 00:00:00', freq='D'),
#  Timestamp('2020-03-16 00:00:00', freq='D'),
#  Timestamp('2020-03-17 00:00:00', freq='D'),
#  Timestamp('2020-03-18 00:00:00', freq='D'),
#  Timestamp('2020-03-19 00:00:00', freq='D'),
#  Timestamp('2020-03-20 00:00:00', freq='D'),
#  Timestamp('2020-03-21 00:00:00', freq='D'),
# ...

# %%
result.to_json(r'D:/Visual Studio Python Projects/Twitter Dataset/Apple/AAPL1.json')

# %%
result = result.set_index(['Date'])

# %%
for date in dates:
    times = result.loc[date]
    print(len(times))
# Out:
# 341
# 1348
# 1389
# 970
# 1026
# 1053
# 314
# 335
# 1280
# 1148
# 1047
# 1425
# 1460
# 595
# 534
# 1372
# 1153
# 1205
# 966
# 949
# 438
# 423
# 1271
# 1017
# 1104
# 985
# 787
# 262
# 300
# 693
# 902
# 900
# 786
# 872
# 284
# 281
# 951
# 945
# 760
# 852
# 398
# 267
# 230
# 1087
# 1437
# 1088
# 1205
# 1506
# 366
# 337
# 913
# 1147
# 881
# 1032
# 947
# 409
# 437
# 1122
# 850
# 891
# 2698
# 3727
# 820
# 867
# 2396
# 2492
# 2203
# 1957
# 2392
# 786
# 690
# 2514
# 3004
# 2210
# 2069
# 2452
# 606
# 767
# 1879
# 2150
# 1948
# 1662
# 1348
# 709
# 508
# 859
# 1921
# 1748
# 2050
# 1468
# 591
# 657
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\python3newenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
# ...

# %%
tweets_df8 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/appleoctober.json', lines=True)
tweets_df8
# Out:
#                                                      url  \
# 0      https://twitter.com/ArabianInvestor/status/132...
# 1      https://twitter.com/Starman__1/status/13226887...
# 2      https://twitter.com/Investidea1/status/1322688...
# 3      https://twitter.com/Fernand43240669/status/132...
# 4      https://twitter.com/David_Beharall/status/1322...
# ...                                                  ...
# 60101  https://twitter.com/David_Beharall/status/1311...
# 60102  https://twitter.com/ztinvesting/status/1311456...
# 60103  https://twitter.com/DudeWhoTrades/status/13114...
# 60104  https://twitter.com/pas_fou1972/status/1311455...
# 60105  https://twitter.com/David_Beharall/status/1311...
#
#                            date  \
# 0     2020-10-31 23:58:00+00:00
# 1     2020-10-31 23:55:46+00:00
# 2     2020-10-31 23:55:39+00:00
# 3     2020-10-31 23:50:55+00:00
# 4     2020-10-31 23:50:00+00:00
# ...                         ...
# 60101 2020-10-01 00:05:00+00:00
# ...

# %%
tweets_df9 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/applenovember.json', lines=True)
tweets_df9
# Out:
#                                                      url  \
# 0      https://twitter.com/Disneybeachlv/status/13335...
# 1      https://twitter.com/MeetTheDealer/status/13335...
# 2      https://twitter.com/dhaval_kotecha/status/1333...
# 3      https://twitter.com/MasaSonCap/status/13335608...
# 4      https://twitter.com/TradeLikeGates/status/1333...
# ...                                                  ...
# 34970  https://twitter.com/Aehreen/status/13226925180...
# 34971  https://twitter.com/David_Beharall/status/1322...
# 34972  https://twitter.com/Fernand43240669/status/132...
# 34973  https://twitter.com/c2412345/status/1322689848...
# 34974  https://twitter.com/David_Beharall/status/1322...
#
#                            date  \
# 0     2020-11-30 23:59:32+00:00
# 1     2020-11-30 23:59:02+00:00
# 2     2020-11-30 23:58:29+00:00
# 3     2020-11-30 23:57:38+00:00
# 4     2020-11-30 23:55:36+00:00
# ...                         ...
# 34970 2020-11-01 00:10:45+00:00
# ...

# %%
tweets_df10 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/appledecember.json', lines=True)
tweets_df10
# Out:
#                                                      url  \
# 0      https://twitter.com/MacHashNews/status/1344794...
# 1      https://twitter.com/BullishJason/status/134479...
# 2      https://twitter.com/SmartOptionsAi/status/1344...
# 3      https://twitter.com/BullishJason/status/134479...
# 4      https://twitter.com/BullishJason/status/134479...
# ...                                                  ...
# 46176  https://twitter.com/SultanOf_Swing/status/1333...
# 46177  https://twitter.com/weeklystockchar/status/133...
# 46178  https://twitter.com/TrueBubbleHead/status/1333...
# 46179  https://twitter.com/concord_trading/status/133...
# 46180  https://twitter.com/chad_odell92/status/133356...
#
#                            date  \
# 0     2020-12-31 23:57:33+00:00
# 1     2020-12-31 23:56:34+00:00
# 2     2020-12-31 23:56:29+00:00
# 3     2020-12-31 23:53:55+00:00
# 4     2020-12-31 23:53:06+00:00
# ...                         ...
# 46176 2020-12-01 00:03:29+00:00
# ...

# %%
tweets_df11 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/applejanuary.json', lines=True)
tweets_df11
# Out:
#                                                      url  \
# 0      https://twitter.com/DYTRDR1/status/13560294022...
# 1      https://twitter.com/StuSim/status/135602937801...
# 2      https://twitter.com/Roy_Wainer/status/13560280...
# 3      https://twitter.com/TrendSpider/status/1356028...
# 4      https://twitter.com/TATrades/status/1356027597...
# ...                                                  ...
# 52820  https://twitter.com/PickStocks3/status/1344796...
# 52821  https://twitter.com/ddandaneau/status/13447960...
# 52822  https://twitter.com/HaltTrade/status/134479574...
# 52823  https://twitter.com/itsdird/status/13447957231...
# 52824  https://twitter.com/StockMKTNewz/status/134479...
#
#                            date  \
# 0     2021-01-31 23:59:37+00:00
# 1     2021-01-31 23:59:32+00:00
# 2     2021-01-31 23:54:08+00:00
# 3     2021-01-31 23:54:04+00:00
# 4     2021-01-31 23:52:27+00:00
# ...                         ...
# 52820 2021-01-01 00:03:28+00:00
# ...

# %%
tweets_df12 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/applefebruary.json', lines=True)
tweets_df12
# Out:
#                                                      url  \
# 0      https://twitter.com/gzbenso/status/13661761575...
# 1      https://twitter.com/gzbenso/status/13661758412...
# 2      https://twitter.com/insight_chart/status/13661...
# 3      https://twitter.com/Colt45trade/status/1366175...
# 4      https://twitter.com/gzbenso/status/13661754375...
# ...                                                  ...
# 48759  https://twitter.com/TopStockAlerts1/status/135...
# 48760  https://twitter.com/toushiinu/status/135602997...
# 48761  https://twitter.com/1980_naomi/status/13560298...
# 48762  https://twitter.com/GustavooNunez/status/13560...
# 48763  https://twitter.com/11Graphs/status/1356029707...
#
#                            date  \
# 0     2021-02-28 23:59:12+00:00
# 1     2021-02-28 23:57:57+00:00
# 2     2021-02-28 23:57:23+00:00
# 3     2021-02-28 23:57:07+00:00
# 4     2021-02-28 23:56:21+00:00
# ...                         ...
# 48759 2021-02-01 00:04:51+00:00
# ...

# %%
tweets_df14 = pd.read_json('D:/Visual Studio Python Projects/Twitter Dataset/Apple/applemarch21.json', lines=True)
tweets_df14
# Out:
#                                                      url  \
# 0      https://twitter.com/BlaineCapital/status/13774...
# 1      https://twitter.com/B_RadTee/status/1377409637...
# 2      https://twitter.com/ScottRutt/status/137740962...
# 3      https://twitter.com/stocksandteeth/status/1377...
# 4      https://twitter.com/panyaguayepo/status/137740...
# ...                                                  ...
# 52731  https://twitter.com/toriotrades/status/1366176...
# 52732  https://twitter.com/PortfolioBuzz/status/13661...
# 52733  https://twitter.com/11Graphs/status/1366176569...
# 52734  https://twitter.com/JWalkeReklaW/status/136617...
# 52735  https://twitter.com/EliteOptions2/status/13661...
#
#                            date  \
# 0     2021-03-31 23:58:34+00:00
# 1     2021-03-31 23:57:03+00:00
# 2     2021-03-31 23:57:00+00:00
# 3     2021-03-31 23:56:46+00:00
# 4     2021-03-31 23:56:25+00:00
# ...                         ...
# 52731 2021-03-01 00:02:25+00:00
# ...

# %%
frames = [tweets_df1, tweets_df2, tweets_df3,tweets_df4,tweets_df5,tweets_df6,tweets_df7,tweets_df8,tweets_df9,tweets_df10,tweets_df11,tweets_df12,tweets_df14]
result = pd.concat(frames)

# %%
result.reset_index(inplace=True)

# %%
result
# Out:
#         index                                                url  \
# 0           0  https://twitter.com/ExactOptionPick/status/124...
# 1           1  https://twitter.com/treabase/status/1245137572...
# 2           2  https://twitter.com/WolfOfWeedST/status/124513...
# 3           3  https://twitter.com/EliteOptions2/status/12451...
# 4           4  https://twitter.com/PortfolioBuzz/status/12451...
# ...       ...                                                ...
# 585470  52731  https://twitter.com/toriotrades/status/1366176...
# 585471  52732  https://twitter.com/PortfolioBuzz/status/13661...
# 585472  52733  https://twitter.com/11Graphs/status/1366176569...
# 585473  52734  https://twitter.com/JWalkeReklaW/status/136617...
# 585474  52735  https://twitter.com/EliteOptions2/status/13661...
#
#                             date  \
# 0      2020-03-31 23:59:09+00:00
# 1      2020-03-31 23:55:05+00:00
# 2      2020-03-31 23:53:20+00:00
# 3      2020-03-31 23:45:53+00:00
# ...

# %%
result.reset_index(inplace=True)

# %%
from datetime import datetime
result['Date'] = result['date'].dt.date

# %%
dates = list(pd.date_range(start="2020-03-01",end="2021-03-31"))

# %%
result = result.set_index(['Date'])

# %%
import yfinance as yf
import pandas as pd
import statsmodels
import numpy as np
import datetime
import time
from pandas_datareader import data as pdr
yf.pdr_override()
from statsmodels.tsa.stattools import adfuller
import pandas as pd
import numpy as np
# %matplotlib inline
import statistics
import requests #The requests library for HTTP requests in Python
import xlsxwriter #The XlsxWriter libarary for 
import math #The Python math module
from scipy import stats #The SciPy stats module
from textblob import TextBlob

# %%
result["sentiment"] = result["content"].apply(lambda tweet: TextBlob(tweet).sentiment.polarity)

# %%
for date in dates:
    tweets = np.mean(result.loc[date,'sentiment'])
    print(date,tweets)

# %%
for date in dates:
    times = result.loc[date]
    print(len(times))
# Out:
# 341
# 1348
# 1389
# 970
# 1026
# 1053
# 314
# 335
# 1280
# 1148
# 1047
# 1425
# 1460
# 595
# 534
# 1372
# 1153
# 1205
# 966
# 949
# 438
# 423
# 1271
# 1017
# 1104
# 985
# 787
# 262
# 300
# 693
# 902
# 900
# 786
# 872
# 284
# 281
# 951
# 945
# 760
# 852
# 398
# 267
# 230
# 1087
# 1437
# 1088
# 1205
# 1506
# 366
# 337
# 913
# 1147
# 881
# 1032
# 947
# 409
# 437
# 1122
# 850
# 891
# 2698
# 3727
# 820
# 867
# 2396
# 2492
# 2203
# 1957
# 2392
# 786
# 690
# 2514
# 3004
# 2210
# 2069
# 2452
# 606
# 767
# 1879
# 2150
# 1948
# 1662
# 1348
# 709
# 508
# 859
# 1921
# 1748
# 2050
# 1468
# 591
# 657
# 835
# 978
# 1038
# 771
# 1393
# 432
# 492
# 1009
# 1920
# 1780
# 1538
# 1184
# 386
# 549
# 1128
# 1464
# 1272
# 1145
# 1792
# 516
# 508
# 2196
# 2611
# 1682
# 1389
# 1210
# 461
# 532
# 1208
# 1455
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...
